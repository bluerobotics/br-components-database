# %%
import kiutils.symbol
import random
import os
import glob
import pandas as pd

#### Function for generating a unique BR ID ####
def generate_BRID(existing_BRIDs):

    # Set number of digits in unique BRID
    num_digits = 6      

    # Increment by 1 until the BRID doesn't exist
    for n in range(10**num_digits):

        # Convert to a zero padded string (to fill the desired number of digits -- e.g, 1 --> '0001')
        BR_num = str(n).zfill(num_digits)
        BRID = 'BRE-' + BR_num

        # If the new BRID isn't currently used, we've found the one!
        if BRID not in existing_BRIDs:
            break

    return BRID

def add_field_to_symbol(symbol_lib, symbol_name, field_name, field_value):
    """
    Add a custom field to a KiCad symbol (.kicad_sym file) using kiutils.

    Args:
        symbol_lib (kiutils SymbolLib): symbol_lib object being read
        symbol_name (str): The name of the symbol to modify.
        field_name (str): The name of the field to add.
        field_value (str): The value of the field to add.
    """

    # Find the symbol by name
    symbol = None
    for sym in symbol_lib.symbols:
        if sym.libId == symbol_name:
            symbol = sym
            break

    if symbol is None:
        raise ValueError(f'Symbol "{symbol_name}" not found in the library.')

    # Create the new field using kiutils' built-in property structure
    field_id = len(symbol.properties)  # Set ID to the next available index
    new_field = kiutils.symbol.Property(key=field_name, value=field_value, id=field_id)

    # Add the new field to the symbol's properties
    symbol.properties.append(new_field)

    # Save the modified symbol back to the file
    print(f'Field "{field_name}" with value "{field_value}" added to symbol "{symbol_name}".')

# %%
parts_df = pd.DataFrame(columns=['ID','Name','Description','Value','Symbol','Footprint','Datasheet','Manufacturer','MPN', 'Category'])
vendors_df = pd.DataFrame(columns=['ID','Supplier','SPN','Stock'])

ID_list = []
parts_list = []
vendors_list = []

# Reading symbol libraries from our BR symbols folder
SYMBOLS_PATH = "C:/Users/JacobBrotmanKrass/Documents/GitHub/br-kicad-lib/Symbols"
os.chdir(SYMBOLS_PATH)
for lib_file in glob.glob("*.kicad_sym"):

    # Extract library nickname/category -- e.g., 0402_Capacitors
    lib_nickname = lib_file.replace(".kicad_sym", "")

    # Skip these libraries, they don't need to be documented (obsolete or not actual parts)
    if (lib_nickname == "BR~Deprecated") or (lib_nickname == "BR_Virtual_Parts"):
        continue
    print(lib_nickname)

    # Open symbol library
    lib_path = os.path.join(SYMBOLS_PATH, lib_file)
    symbol_lib = kiutils.symbol.SymbolLib().from_file(lib_path)
    
    # The Category is the library nickname, without the BR_ at the beginning
    category = lib_nickname[3:]

    # For each symbol in a given library, populate a new row in the Parts dataframe
    for symbol in symbol_lib.symbols:

        # Symbol path in Kicad
        symbol_path = f"{lib_nickname}:{symbol.entryName}"

        # Generate a unique BR ID --- Only necessary for this first commit of Kicad parts into our BR "database"
        BR_ID = generate_BRID(ID_list)
        ID_list.append(BR_ID)

        # Grab all the properties from the Kicad Symbol
        properties = {property.key: property.value for property in symbol.properties}

        # Remove a weird decoding error with the plus/minus sign
        bad_char = b'\xc3\x82'.decode()
        properties["Description"] = properties["Description"].replace(bad_char, '')

        # Some parts don't have a manufacturer and manufacturer part number -- deal with this some other time, for now just populate "None"
        if "Manufacturer" in properties:
            manufacturer = properties["Manufacturer"]
            mpn = properties["Manufacturer Part Num"]
        else:
            manufacturer = "None"
            mpn = "None"

        # Append a dictionary of all part properties to the parts list -- this will be converted to a Pandas dataframe at the end
        parts_list.append({"BR ID":BR_ID, "Name":symbol.libId, "Description":properties["Description"], "Value":properties["Value"], "Symbol":symbol_path, "Footprint":properties["Footprint"],  "Datasheet":properties["Datasheet"], "Manufacturer":manufacturer, "MPN":mpn, "Category":category})

        # Add BR ID to the symbol
        add_field_to_symbol(symbol_lib, symbol.libId, "BR ID", BR_ID)

        # Extract all supplier-related properties: supplier X with suppler number X
        supplier_properties = {property: properties[property] for property in properties if property[:8]=="Supplier"}
        supplier_numbers = {supp_prop: supplier_properties[supp_prop] for supp_prop in supplier_properties if supp_prop[9]=='P'}
        supplier_names = {supp_prop: supplier_properties[supp_prop] for supp_prop in supplier_properties if supp_prop[9]!='P'}

        # Ignore any thing that looks like this
        null_strings = ["", " ", "-", "--", "~", "NA", "N/A"]

        # Loop through and add vendors and the respective supplier number when the number X at the end matches (supplier 1 --> supplier part num 1)
        for name in supplier_names:
            for number in supplier_numbers:
                if name[-1] == number[-1]:
                    if supplier_numbers[number] not in null_strings:

                        # Append dictionary of supplier properties for each SPN to the vendors list
                        # this will be converted to Pandas dataframe at the end
                        vendors_list.append({"BR ID":BR_ID, "Supplier":supplier_names[name], "SPN":supplier_numbers[number], "Stock":0})

    symbol_lib.to_file()

# Create Pandas dataframes from these lists of dictionaries
# Think of each dictionary as a row in the table
parts_df = pd.DataFrame(parts_list)
vendors_df = pd.DataFrame(vendors_list)

# Create dataframe from the JLC scrape spreadsheet
jlc_df = pd.read_excel(r"C:\Users\JacobBrotmanKrass\Documents\GitHub\br-components-database\jlc-scraper\csv\Parts Inventory on JLCPCB.xlsx")

# Merge the vendors and JLC dataframes by Supplier Part Number
jlc_df.rename(columns={"JLCPCB Part #":"SPN"}, inplace=True)
merged_df = pd.merge(vendors_df.set_index("SPN"), jlc_df.set_index("SPN"), on="SPN", how='left')

# Populate the stock column using the maximum value of the three sources of JLC stock
merged_df["Stock"] = merged_df[["JLCPCB Parts Qty", "Global Sourcing Parts Qty", "Consigned Parts Qty"]].max(axis=1)

# I think we only want the BR ID, Supplier, SPN, and Stock columns
vendor_stock_df = merged_df.reset_index()[["BR ID", "Supplier", "SPN", "Stock"]]

# Create a hierarchical index using the BR ID and its various associated supplier part numbers 
vendor_stock_df.set_index(["BR ID", "SPN"], inplace=True)

# Save dataframes to excel files
vendor_stock_df.to_excel("C:/Users/JacobBrotmanKrass/Documents/Vendor_Stock.xlsx")
parts_df.to_excel("C:/Users/JacobBrotmanKrass/Documents/Parts_Library.xlsx")
# Out:
# BR_Capacitors_0201
# Field "BR ID" with value "BRE-000000" added to symbol "C_0201_100nF_25V_X7R_10%".
# Field "BR ID" with value "BRE-000001" added to symbol "C_0201_10nF_25V_X7R_10%".
# Field "BR ID" with value "BRE-000002" added to symbol "C_0201_1nF_50V_C0G_1%".
# Field "BR ID" with value "BRE-000003" added to symbol "C_0201_1uF_16V_X5R_10%".
# Field "BR ID" with value "BRE-000004" added to symbol "C_0201_220nF_25V_X5R_10%".
# Field "BR ID" with value "BRE-000005" added to symbol "C_0201_3p9F_50V_C0G_5%".
# Field "BR ID" with value "BRE-000006" added to symbol "C_0201_470nF_6V3_X5R_10%".
# Field "BR ID" with value "BRE-000007" added to symbol "C_0201_470pF_50V_C0G_5%".
# Field "BR ID" with value "BRE-000008" added to symbol "C_0201_4n7F_25V_X7R_10%".
# Field "BR ID" with value "BRE-000009" added to symbol "C_0201_6pF_50V_C0G_15%".
# BR_Capacitors_0402
# Field "BR ID" with value "BRE-000010" added to symbol "C_0402_100nF_50V_X7R_10%_AEC-Q200_mini".
# Field "BR ID" with value "BRE-000011" added to symbol "C_0402_100pF".
# Field "BR ID" with value "BRE-000012" added to symbol "C_0402_10nF_35V_X7R_2%".
# Field "BR ID" with value "BRE-000013" added to symbol "C_0402_10nF_50V_X7R".
# Field "BR ID" with value "BRE-000014" added to symbol "C_0402_10pF".
# Field "BR ID" with value "BRE-000015" added to symbol "C_0402_10uF_10V".
# Field "BR ID" with value "BRE-000016" added to symbol "C_0402_10uF_6V3_X5R".
# Field "BR ID" with value "BRE-000017" added to symbol "C_0402_16pF".
# Field "BR ID" with value "BRE-000018" added to symbol "C_0402_1nF_50V_NP0_5%".
# Field "BR ID" with value "BRE-000019" added to symbol "C_0402_1uF_10V_X7R_10%".
# Field "BR ID" with value "BRE-000020" added to symbol "C_0402_1uF_50V_X5R_20%".
# Field "BR ID" with value "BRE-000021" added to symbol "C_0402_220nF_10V_X7R_10%".
# Field "BR ID" with value "BRE-000022" added to symbol "C_0402_22nF_10V_X7R_10%".
# Field "BR ID" with value "BRE-000023" added to symbol "C_0402_22pF".
# Field "BR ID" with value "BRE-000024" added to symbol "C_0402_2u2F_10V_X7R_10%".
# Field "BR ID" with value "BRE-000025" added to symbol "C_0402_330nF_6V3".
# Field "BR ID" with value "BRE-000026" added to symbol "C_0402_33nF".
# Field "BR ID" with value "BRE-000027" added to symbol "C_0402_3p9F".
# Field "BR ID" with value "BRE-000028" added to symbol "C_0402_470nF_10V_X7R".
# Field "BR ID" with value "BRE-000029" added to symbol "C_0402_470pF_50V_X7R".
# Field "BR ID" with value "BRE-000030" added to symbol "C_0402_47nF_50V_X7R_10%_mini".
# Field "BR ID" with value "BRE-000031" added to symbol "C_0402_47pF".
# Field "BR ID" with value "BRE-000032" added to symbol "C_0402_4n7F_100V_X7R_10%".
# Field "BR ID" with value "BRE-000033" added to symbol "C_0402_4u7F_10V_X7T_20%_mini".
# Field "BR ID" with value "BRE-000034" added to symbol "C_0402_4u7F_6V3".
# BR_Capacitors_0603
# Field "BR ID" with value "BRE-000035" added to symbol "C_0603_100nF".
# Field "BR ID" with value "BRE-000036" added to symbol "C_0603_100nF_100V_X7R".
# Field "BR ID" with value "BRE-000037" added to symbol "C_0603_10uF_10V_X7T_10%".
# Field "BR ID" with value "BRE-000038" added to symbol "C_0603_10uF_16V".
# Field "BR ID" with value "BRE-000039" added to symbol "C_0603_1uF".
# Field "BR ID" with value "BRE-000040" added to symbol "C_0603_1uF_25V_X7R_10%_AEC-Q200_mini".
# Field "BR ID" with value "BRE-000041" added to symbol "C_0603_1uF_50V_X7R_10%_AEC-Q200_mini".
# Field "BR ID" with value "BRE-000042" added to symbol "C_0603_220nF".
# Field "BR ID" with value "BRE-000043" added to symbol "C_0603_22uF_10V".
# Field "BR ID" with value "BRE-000044" added to symbol "C_0603_22uF_16V".
# Field "BR ID" with value "BRE-000045" added to symbol "C_0603_2u2F_50V_X5R".
# Field "BR ID" with value "BRE-000046" added to symbol "C_0603_47nF_50V_X8R_5%_mini".
# Field "BR ID" with value "BRE-000047" added to symbol "C_0603_47uF_6V3_X5R".
# Field "BR ID" with value "BRE-000048" added to symbol "C_0603_4u7F_16V_X5R".
# BR_Capacitors_0805
# Field "BR ID" with value "BRE-000049" added to symbol "C_0805_10uF_25V_X7R_10%_mini".
# Field "BR ID" with value "BRE-000050" added to symbol "C_0805_10uF_50V_X5R".
# Field "BR ID" with value "BRE-000051" added to symbol "C_0805_1nF_1kV_X7R_10%".
# Field "BR ID" with value "BRE-000052" added to symbol "C_0805_1uF".
# Field "BR ID" with value "BRE-000053" added to symbol "C_0805_1uF_25V_X8R_10%_AEC-200_mini".
# Field "BR ID" with value "BRE-000054" added to symbol "C_0805_22uF".
# Field "BR ID" with value "BRE-000055" added to symbol "C_0805_22uF_25V_X5R".
# Field "BR ID" with value "BRE-000056" added to symbol "C_0805_2u2F".
# Field "BR ID" with value "BRE-000057" added to symbol "C_0805_470nF_100V_X7R_10%".
# Field "BR ID" with value "BRE-000058" added to symbol "C_0805_47uF".
# Field "BR ID" with value "BRE-000059" added to symbol "C_0805_4u7F".
# Field "BR ID" with value "BRE-000060" added to symbol "C_0805_4u7F_50V_X7R_10%_AEC-Q200_mini".
# BR_Capacitors_1206
# Field "BR ID" with value "BRE-000061" added to symbol "C_1206_10uF_50V_X5R_20%".
# Field "BR ID" with value "BRE-000062" added to symbol "C_1206_10uF_50V_X7R_10%_mini".
# Field "BR ID" with value "BRE-000063" added to symbol "C_1206_1nF_2kV_X7R_10%".
# Field "BR ID" with value "BRE-000064" added to symbol "C_1206_22uF_10V_X7R_10%_mini".
# Field "BR ID" with value "BRE-000065" added to symbol "C_1206_47uF_10V_X5R_20%".
# Field "BR ID" with value "BRE-000066" added to symbol "C_1206_47uF_6V3_X7S_20%_mini".
# BR_Capacitors_1210
# Field "BR ID" with value "BRE-000067" added to symbol "C_1210_10uF_100V_X7S".
# BR_Connectors
# Field "BR ID" with value "BRE-000068" added to symbol "284093-6".
# Field "BR ID" with value "BRE-000069" added to symbol "4UCON_15379_2x20".
# Field "BR ID" with value "BRE-000070" added to symbol "4UCON_15872_3x16".
# Field "BR ID" with value "BRE-000071" added to symbol "Conn_01x03".
# Field "BR ID" with value "BRE-000072" added to symbol "Conn_01x04".
# Field "BR ID" with value "BRE-000073" added to symbol "Conn_01x08".
# Field "BR ID" with value "BRE-000074" added to symbol "Conn_01x12".
# Field "BR ID" with value "BRE-000075" added to symbol "Conn_02x05_Odd_Even".
# Field "BR ID" with value "BRE-000076" added to symbol "Conn_02x05_SMD".
# Field "BR ID" with value "BRE-000077" added to symbol "Conn_02x05_SMD_Socket".
# Field "BR ID" with value "BRE-000078" added to symbol "Conn_03x03".
# Field "BR ID" with value "BRE-000079" added to symbol "Conn_03x16".
# Field "BR ID" with value "BRE-000080" added to symbol "DS1129-04-S8B0P-X".
# Field "BR ID" with value "BRE-000081" added to symbol "KYOCERA_AVX_009176001853906".
# Field "BR ID" with value "BRE-000082" added to symbol "KYOCERA_AVX_009176001884906".
# Field "BR ID" with value "BRE-000083" added to symbol "KYOCERA_AVX_009176004873906".
# Field "BR ID" with value "BRE-000084" added to symbol "MSD-1-A".
# Field "BR ID" with value "BRE-000085" added to symbol "Micro_SD_Card_Det1".
# Field "BR ID" with value "BRE-000086" added to symbol "PM127-2-04-S-4.3".
# Field "BR ID" with value "BRE-000087" added to symbol "PZ127-2-04-S".
# Field "BR ID" with value "BRE-000088" added to symbol "Pin_Header_02x10_2mm_Horizontal_SMD".
# Field "BR ID" with value "BRE-000089" added to symbol "Pin_Header_02x12_2.54mm_Horizontal_SMD".
# Field "BR ID" with value "BRE-000090" added to symbol "Pin_Header_02x12_2.54mm_Horizontal_SMD_CHEAP".
# Field "BR ID" with value "BRE-000091" added to symbol "Pin_Socket_02x10_2mm_Horizontal_SMD".
# Field "BR ID" with value "BRE-000092" added to symbol "Pin_Socket_02x12_2.54mm_Horizontal_SMD".
# Field "BR ID" with value "BRE-000093" added to symbol "Pin_Socket_02x12_2.54mm_Horizontal_THT_CHEAP".
# Field "BR ID" with value "BRE-000094" added to symbol "RC01812".
# Field "BR ID" with value "BRE-000095" added to symbol "Raspberry_Pi_4-Connector2".
# Field "BR ID" with value "BRE-000096" added to symbol "TP_RING_TH".
# Field "BR ID" with value "BRE-000097" added to symbol "U77A1118200T".
# Field "BR ID" with value "BRE-000098" added to symbol "UE75-A20-6000T".
# Field "BR ID" with value "BRE-000099" added to symbol "USB-C_GSB1CA11101DSHR".
# Field "BR ID" with value "BRE-000100" added to symbol "etray_backplane_bus_bar".
# Field "BR ID" with value "BRE-000101" added to symbol "etray_blackplane_power_connector".
# BR_Connectors_FFC
# Field "BR ID" with value "BRE-000102" added to symbol "0.5K-A-16PB".
# Field "BR ID" with value "BRE-000103" added to symbol "2328702-6".
# Field "BR ID" with value "BRE-000104" added to symbol "MOLEX_5034801600".
# Field "BR ID" with value "BRE-000105" added to symbol "X05A20H16G".
# BR_Connectors_JST_GH
# Field "BR ID" with value "BRE-000106" added to symbol "BM02B-GHS-TBT".
# Field "BR ID" with value "BRE-000107" added to symbol "BM03B-GHS-TBT".
# Field "BR ID" with value "BRE-000108" added to symbol "BM04B-GHS-TBT".
# Field "BR ID" with value "BRE-000109" added to symbol "BM05B-GHS-TBT".
# Field "BR ID" with value "BRE-000110" added to symbol "BM06B-GHS-TBT".
# Field "BR ID" with value "BRE-000111" added to symbol "BM08B-GHS-TBT".
# Field "BR ID" with value "BRE-000112" added to symbol "SM02B-GHS-TB".
# Field "BR ID" with value "BRE-000113" added to symbol "SM03B-GHS-TB".
# Field "BR ID" with value "BRE-000114" added to symbol "SM04B-GHS-TB".
# Field "BR ID" with value "BRE-000115" added to symbol "SM05B-GHS-TB".
# Field "BR ID" with value "BRE-000116" added to symbol "SM06B-GHS-TB".
# BR_Connectors_JST_misc
# Field "BR ID" with value "BRE-000117" added to symbol "JST_SM02B-PASS-TBT_LF_SNJST_SM02B-PASS-TBT_LF_SN_0_0".
# Field "BR ID" with value "BRE-000118" added to symbol "SM10B-SURS-TF".
# BR_Connectors_Molex_misc
# Field "BR ID" with value "BRE-000119" added to symbol "476150001".
# Field "BR ID" with value "BRE-000120" added to symbol "Pico-EZmate_Slim_2026560021".
# BR_Connectors_Molex_Picoblade
# Field "BR ID" with value "BRE-000121" added to symbol "53261-0271".
# Field "BR ID" with value "BRE-000122" added to symbol "53261-0371".
# Field "BR ID" with value "BRE-000123" added to symbol "53261-0471".
# Field "BR ID" with value "BRE-000124" added to symbol "53261-0671".
# Field "BR ID" with value "BRE-000125" added to symbol "53261-0871".
# Field "BR ID" with value "BRE-000126" added to symbol "53398-0671".
# BR_Crystals
# Field "BR ID" with value "BRE-000127" added to symbol "831056295".
# Field "BR ID" with value "BRE-000128" added to symbol "NX2016SA-25MHZ".
# Field "BR ID" with value "BRE-000129" added to symbol "X322525MQB4SI".
# BR_Diodes
# Field "BR ID" with value "BRE-000130" added to symbol "B160AF-13".
# Field "BR ID" with value "BRE-000131" added to symbol "B260AF-13".
# Field "BR ID" with value "BRE-000132" added to symbol "BAV116W-7-F".
# Field "BR ID" with value "BRE-000133" added to symbol "BZT52C5V6".
# Field "BR ID" with value "BRE-000134" added to symbol "MBR0520LT1G".
# Field "BR ID" with value "BRE-000135" added to symbol "MM1Z62B".
# Field "BR ID" with value "BRE-000136" added to symbol "MM3Z10VT1G".
# Field "BR ID" with value "BRE-000137" added to symbol "MMBD1501A".
# Field "BR ID" with value "BRE-000138" added to symbol "PJGBLC12C_R1_00001".
# Field "BR ID" with value "BRE-000139" added to symbol "PMEG3010AESB".
# Field "BR ID" with value "BRE-000140" added to symbol "PMEG4002EB".
# Field "BR ID" with value "BRE-000141" added to symbol "RB520S-30".
# Field "BR ID" with value "BRE-000142" added to symbol "SMA33CA".
# Field "BR ID" with value "BRE-000143" added to symbol "SMAJ54CA".
# Field "BR ID" with value "BRE-000144" added to symbol "SP4021-01FTG-C".
# Field "BR ID" with value "BRE-000145" added to symbol "SS8PH10-M3/86A".
# Field "BR ID" with value "BRE-000146" added to symbol "USBLC6-2SC6".
# Field "BR ID" with value "BRE-000147" added to symbol "USBLC6-2P6".
# BR_Electromechanical
# Field "BR ID" with value "BRE-000148" added to symbol "1722RB-9".
# BR_IC
# Field "BR ID" with value "BRE-000149" added to symbol "ADC088S022".
# Field "BR ID" with value "BRE-000150" added to symbol "ADS1115IDGS".
# Field "BR ID" with value "BRE-000151" added to symbol "CAT24C32WI-GT3".
# Field "BR ID" with value "BRE-000152" added to symbol "DSC6101HA3B-025.0000".
# Field "BR ID" with value "BRE-000153" added to symbol "HV7802MG-G".
# Field "BR ID" with value "BRE-000154" added to symbol "M24C02-RMN".
# Field "BR ID" with value "BRE-000155" added to symbol "M74VHC1GT50DTT1G".
# Field "BR ID" with value "BRE-000156" added to symbol "MAX31740ATA+T".
# Field "BR ID" with value "BRE-000157" added to symbol "MCP2542FD".
# Field "BR ID" with value "BRE-000158" added to symbol "MCP2542WFD".
# Field "BR ID" with value "BRE-000159" added to symbol "PCA9685PW".
# Field "BR ID" with value "BRE-000160" added to symbol "SN65HVD75DRBR".
# Field "BR ID" with value "BRE-000161" added to symbol "SN74LV1T34DBVR".
# Field "BR ID" with value "BRE-000162" added to symbol "STM32G071KBU6".
# Field "BR ID" with value "BRE-000163" added to symbol "STM32G071KBU6N".
# Field "BR ID" with value "BRE-000164" added to symbol "STM32G491REIx".
# Field "BR ID" with value "BRE-000165" added to symbol "STM32H563AGI6".
# Field "BR ID" with value "BRE-000166" added to symbol "STM32H563AGI6Q".
# Field "BR ID" with value "BRE-000167" added to symbol "STM32H563MIY3QTR".
# Field "BR ID" with value "BRE-000168" added to symbol "STM32H563RGV6".
# Field "BR ID" with value "BRE-000169" added to symbol "STM32H573AII6".
# Field "BR ID" with value "BRE-000170" added to symbol "THVD1420DRLR".
# Field "BR ID" with value "BRE-000171" added to symbol "TPS2121RUXR".
# Field "BR ID" with value "BRE-000172" added to symbol "TXS0102YZPR".
# Field "BR ID" with value "BRE-000173" added to symbol "W25Q64JVSSIQ".
# BR_IC_Ethernet
# Field "BR ID" with value "BRE-000174" added to symbol "88LX2730A0-NYC2C000".
# Field "BR ID" with value "BRE-000175" added to symbol "88LX2741A0-NYC2I000".
# Field "BR ID" with value "BRE-000176" added to symbol "88LX5153A0-BUU2C000".
# Field "BR ID" with value "BRE-000177" added to symbol "DP83822IRHBR".
# Field "BR ID" with value "BRE-000178" added to symbol "DP83825IRMQR".
# Field "BR ID" with value "BRE-000179" added to symbol "KSZ8863".
# Field "BR ID" with value "BRE-000180" added to symbol "KSZ8863RLLI".
# Field "BR ID" with value "BRE-000181" added to symbol "LAN8670".
# Field "BR ID" with value "BRE-000182" added to symbol "LAN8671".
# Field "BR ID" with value "BRE-000183" added to symbol "LAN9354".
# Field "BR ID" with value "BRE-000184" added to symbol "RTL8211E-VB-CG".
# Field "BR ID" with value "BRE-000185" added to symbol "RTL8211F-VD-CG".
# Field "BR ID" with value "BRE-000186" added to symbol "RTL8305NB".
# Field "BR ID" with value "BRE-000187" added to symbol "RTL8367RB-VB-CG".
# Field "BR ID" with value "BRE-000188" added to symbol "SJA1105".
# BR_IC_Gate_Drivers
# Field "BR ID" with value "BRE-000189" added to symbol "DRV8323RHRGZR".
# Field "BR ID" with value "BRE-000190" added to symbol "DRV8323RS".
# Field "BR ID" with value "BRE-000191" added to symbol "DRV8323S".
# Field "BR ID" with value "BRE-000192" added to symbol "MAX1614EUA+".
# BR_IC_Linear
# Field "BR ID" with value "BRE-000193" added to symbol "AP7370-33Y-13".
# Field "BR ID" with value "BRE-000194" added to symbol "LM2901".
# Field "BR ID" with value "BRE-000195" added to symbol "LM2901B".
# Field "BR ID" with value "BRE-000196" added to symbol "LM2901B-QFN16".
# Field "BR ID" with value "BRE-000197" added to symbol "LM358QT".
# Field "BR ID" with value "BRE-000198" added to symbol "LMV321".
# Field "BR ID" with value "BRE-000199" added to symbol "LMV358AID".
# Field "BR ID" with value "BRE-000200" added to symbol "MCP6002T-E/MC".
# Field "BR ID" with value "BRE-000201" added to symbol "MCP6002T-I/MS".
# Field "BR ID" with value "BRE-000202" added to symbol "TL431A".
# Field "BR ID" with value "BRE-000203" added to symbol "TL431QPK".
# Field "BR ID" with value "BRE-000204" added to symbol "TPS7A20-SOT23".
# Field "BR ID" with value "BRE-000205" added to symbol "TPS7A2033".
# BR_IC_Motor_Drivers
# Field "BR ID" with value "BRE-000206" added to symbol "DRV8212P".
# Field "BR ID" with value "BRE-000207" added to symbol "DRV8311H".
# Field "BR ID" with value "BRE-000208" added to symbol "DRV8311P".
# Field "BR ID" with value "BRE-000209" added to symbol "DRV8849RHHR".
# BR_IC_Regulators
# Field "BR ID" with value "BRE-000210" added to symbol "AP64060WU-7".
# Field "BR ID" with value "BRE-000211" added to symbol "LM27313XMFX/NOPB".
# Field "BR ID" with value "BRE-000212" added to symbol "LM3424MH/NOPB".
# Field "BR ID" with value "BRE-000213" added to symbol "LM5122MHX/NOPB".
# Field "BR ID" with value "BRE-000214" added to symbol "LM5160ADNTR".
# Field "BR ID" with value "BRE-000215" added to symbol "LM5163DDAR".
# Field "BR ID" with value "BRE-000216" added to symbol "LM76005RNPR".
# Field "BR ID" with value "BRE-000217" added to symbol "LMR50410SDBVR".
# Field "BR ID" with value "BRE-000218" added to symbol "LMR54410DBVR".
# Field "BR ID" with value "BRE-000219" added to symbol "LMZM23600V3SIL".
# Field "BR ID" with value "BRE-000220" added to symbol "LMZM23600V5SIL".
# Field "BR ID" with value "BRE-000221" added to symbol "MAX20408AFOA/VY+".
# Field "BR ID" with value "BRE-000222" added to symbol "MCP1799T-3302H/TT".
# Field "BR ID" with value "BRE-000223" added to symbol "MIC5365-2.5YC5".
# Field "BR ID" with value "BRE-000224" added to symbol "MIC5365-3.3YC5".
# Field "BR ID" with value "BRE-000225" added to symbol "TLV62569DBVR".
# Field "BR ID" with value "BRE-000226" added to symbol "TPS563300DRL".
# Field "BR ID" with value "BRE-000227" added to symbol "TPS61088RHLR".
# Field "BR ID" with value "BRE-000228" added to symbol "TPS62125DSG".
# Field "BR ID" with value "BRE-000229" added to symbol "TPS923655HMDMTR".
# Field "BR ID" with value "BRE-000230" added to symbol "ZXTR2012FF-7".
# BR_IC_Sensors
# Field "BR ID" with value "BRE-000231" added to symbol "ACS781LLRTR-100U".
# Field "BR ID" with value "BRE-000232" added to symbol "ACS781LLRTR-150U".
# Field "BR ID" with value "BRE-000233" added to symbol "AK09915".
# Field "BR ID" with value "BRE-000234" added to symbol "BMI323".
# Field "BR ID" with value "BRE-000235" added to symbol "BMP390".
# Field "BR ID" with value "BRE-000236" added to symbol "ICM-20602".
# Field "BR ID" with value "BRE-000237" added to symbol "LIS2DH12TR".
# Field "BR ID" with value "BRE-000238" added to symbol "MMC5983-SPI".
# Field "BR ID" with value "BRE-000239" added to symbol "TLE5012B".
# BR_Inductors
# Field "BR ID" with value "BRE-000240" added to symbol "ACM2520-601-2P-T002".
# Field "BR ID" with value "BRE-000241" added to symbol "ASPI-6045T-100M-T".
# Field "BR ID" with value "BRE-000242" added to symbol "AWP_252012FW-4R7M".
# Field "BR ID" with value "BRE-000243" added to symbol "BLM03HG601SN1D".
# Field "BR ID" with value "BRE-000244" added to symbol "BX4550NL".
# Field "BR ID" with value "BRE-000245" added to symbol "CND-WCM0805M801-2".
# Field "BR ID" with value "BRE-000246" added to symbol "CY43-2.2UH".
# Field "BR ID" with value "BRE-000247" added to symbol "G24P02S".
# Field "BR ID" with value "BRE-000248" added to symbol "GA030G00".
# Field "BR ID" with value "BRE-000249" added to symbol "H1102FNL".
# Field "BR ID" with value "BRE-000250" added to symbol "HCB1005KF-121T20".
# Field "BR ID" with value "BRE-000251" added to symbol "HCB_1005KF-221T15".
# Field "BR ID" with value "BRE-000252" added to symbol "HPC5020NF-100M".
# Field "BR ID" with value "BRE-000253" added to symbol "HPC5040NF-100M".
# Field "BR ID" with value "BRE-000254" added to symbol "LSXBD6060WHL100M".
# Field "BR ID" with value "BRE-000255" added to symbol "MFBM1V1608-300-R".
# Field "BR ID" with value "BRE-000256" added to symbol "NR4018T220M".
# Field "BR ID" with value "BRE-000257" added to symbol "NRS4018T2R2MDGJV".
# Field "BR ID" with value "BRE-000258" added to symbol "PSTFAQ3416-600T020".
# Field "BR ID" with value "BRE-000259" added to symbol "QT48A03".
# Field "BR ID" with value "BRE-000260" added to symbol "SMMS0518-R47M".
# Field "BR ID" with value "BRE-000261" added to symbol "SPM10065VT-220M-D".
# Field "BR ID" with value "BRE-000262" added to symbol "SRP0415-R47K".
# Field "BR ID" with value "BRE-000263" added to symbol "SRP0420-4R7K".
# Field "BR ID" with value "BRE-000264" added to symbol "SRP4030FA-3R3M".
# Field "BR ID" with value "BRE-000265" added to symbol "SRP5050FA-6R8M".
# Field "BR ID" with value "BRE-000266" added to symbol "SRP7050WA-100M".
# Field "BR ID" with value "BRE-000267" added to symbol "UT11403S".
# Field "BR ID" with value "BRE-000268" added to symbol "VLS6045EX-101M".
# BR_Modules
# Field "BR ID" with value "BRE-000269" added to symbol "LX200V20-SOCKET".
# Field "BR ID" with value "BRE-000270" added to symbol "LX200V30-SOCKET".
# Field "BR ID" with value "BRE-000271" added to symbol "STLINK-V3MODS".
# BR_Optoelectronic
# Field "BR ID" with value "BRE-000272" added to symbol "APDA1806ZGCK".
# Field "BR ID" with value "BRE-000273" added to symbol "LTST-C191KGKT".
# Field "BR ID" with value "BRE-000274" added to symbol "LTST-C193KFKT-5A".
# Field "BR ID" with value "BRE-000275" added to symbol "LTST-S270KRKT".
# Field "BR ID" with value "BRE-000276" added to symbol "LTST-S270TBKT".
# Field "BR ID" with value "BRE-000277" added to symbol "LTST-S270TGKT".
# Field "BR ID" with value "BRE-000278" added to symbol "ORH-G36G".
# Field "BR ID" with value "BRE-000279" added to symbol "SK6812-SIDE-A".
# Field "BR ID" with value "BRE-000280" added to symbol "SK6812D-EC3210F".
# BR_Resistors_0201
# Field "BR ID" with value "BRE-000281" added to symbol "R_0201_100R_0.1%_25ppm_AEC-Q200_mini".
# Field "BR ID" with value "BRE-000282" added to symbol "R_0201_10R_0.1%_200ppm_mini".
# Field "BR ID" with value "BRE-000283" added to symbol "R_0201_10k_1%".
# Field "BR ID" with value "BRE-000284" added to symbol "R_0201_120R_1%".
# Field "BR ID" with value "BRE-000285" added to symbol "R_0201_12k1_1%".
# Field "BR ID" with value "BRE-000286" added to symbol "R_0201_12k4_0.1%_25ppm_AEC-Q200_mini".
# Field "BR ID" with value "BRE-000287" added to symbol "R_0201_12k4_1%".
# Field "BR ID" with value "BRE-000288" added to symbol "R_0201_15k".
# Field "BR ID" with value "BRE-000289" added to symbol "R_0201_1k_0.1%_25ppm_AEC-Q200_mini".
# Field "BR ID" with value "BRE-000290" added to symbol "R_0201_1k_1%".
# Field "BR ID" with value "BRE-000291" added to symbol "R_0201_20R_1%".
# Field "BR ID" with value "BRE-000292" added to symbol "R_0201_22R_1%".
# Field "BR ID" with value "BRE-000293" added to symbol "R_0201_240R_1%".
# Field "BR ID" with value "BRE-000294" added to symbol "R_0201_30k_1%".
# Field "BR ID" with value "BRE-000295" added to symbol "R_0201_33k_1%".
# Field "BR ID" with value "BRE-000296" added to symbol "R_0201_3k3_0.1%_25ppm_AEC-Q200_mini".
# Field "BR ID" with value "BRE-000297" added to symbol "R_0201_3k_1%".
# Field "BR ID" with value "BRE-000298" added to symbol "R_0201_45k3_1%".
# Field "BR ID" with value "BRE-000299" added to symbol "R_0201_47k_1%".
# Field "BR ID" with value "BRE-000300" added to symbol "R_0201_49R9_1%".
# Field "BR ID" with value "BRE-000301" added to symbol "R_0201_49k9_1%".
# Field "BR ID" with value "BRE-000302" added to symbol "R_0201_4k7_0.1%_25ppm_AEC-Q200_mini".
# Field "BR ID" with value "BRE-000303" added to symbol "R_0201_4k7_1%".
# Field "BR ID" with value "BRE-000304" added to symbol "R_0201_5k9_1%".
# Field "BR ID" with value "BRE-000305" added to symbol "R_0201_681R_1%".
# Field "BR ID" with value "BRE-000306" added to symbol "R_0201_6k04_1%".
# Field "BR ID" with value "BRE-000307" added to symbol "R_0201_6k49_1%".
# Field "BR ID" with value "BRE-000308" added to symbol "R_0201_8k2_0.1%_25ppm_AEC-Q200_mini".
# Field "BR ID" with value "BRE-000309" added to symbol "R_0201_10k_0.1%_25ppm_AEC-Q200_mini".
# BR_Resistors_0402
# Field "BR ID" with value "BRE-000310" added to symbol "RN_0402_220R".
# Field "BR ID" with value "BRE-000311" added to symbol "R_0402_0R".
# Field "BR ID" with value "BRE-000312" added to symbol "R_0402_100k".
# Field "BR ID" with value "BRE-000313" added to symbol "R_0402_10R".
# Field "BR ID" with value "BRE-000314" added to symbol "R_0402_10k".
# Field "BR ID" with value "BRE-000315" added to symbol "R_0402_10k2".
# Field "BR ID" with value "BRE-000316" added to symbol "R_0402_10k5".
# Field "BR ID" with value "BRE-000317" added to symbol "R_0402_110k".
# Field "BR ID" with value "BRE-000318" added to symbol "R_0402_11k8".
# Field "BR ID" with value "BRE-000319" added to symbol "R_0402_120R".
# Field "BR ID" with value "BRE-000320" added to symbol "R_0402_127k".
# Field "BR ID" with value "BRE-000321" added to symbol "R_0402_12k1".
# Field "BR ID" with value "BRE-000322" added to symbol "R_0402_12k4".
# Field "BR ID" with value "BRE-000323" added to symbol "R_0402_130R".
# Field "BR ID" with value "BRE-000324" added to symbol "R_0402_137k".
# Field "BR ID" with value "BRE-000325" added to symbol "R_0402_158k".
# Field "BR ID" with value "BRE-000326" added to symbol "R_0402_15k".
# Field "BR ID" with value "BRE-000327" added to symbol "R_0402_17k4".
# Field "BR ID" with value "BRE-000328" added to symbol "R_0402_17k8".
# Field "BR ID" with value "BRE-000329" added to symbol "R_0402_18k7".
# Field "BR ID" with value "BRE-000330" added to symbol "R_0402_19k6".
# Field "BR ID" with value "BRE-000331" added to symbol "R_0402_1M".
# Field "BR ID" with value "BRE-000332" added to symbol "R_0402_1R".
# Field "BR ID" with value "BRE-000333" added to symbol "R_0402_1k".
# Field "BR ID" with value "BRE-000334" added to symbol "R_0402_1k15".
# Field "BR ID" with value "BRE-000335" added to symbol "R_0402_1k5".
# Field "BR ID" with value "BRE-000336" added to symbol "R_0402_200R".
# Field "BR ID" with value "BRE-000337" added to symbol "R_0402_200k".
# Field "BR ID" with value "BRE-000338" added to symbol "R_0402_20R".
# Field "BR ID" with value "BRE-000339" added to symbol "R_0402_20k".
# Field "BR ID" with value "BRE-000340" added to symbol "R_0402_220R".
# Field "BR ID" with value "BRE-000341" added to symbol "R_0402_22R".
# Field "BR ID" with value "BRE-000342" added to symbol "R_0402_23k2".
# Field "BR ID" with value "BRE-000343" added to symbol "R_0402_240R".
# Field "BR ID" with value "BRE-000344" added to symbol "R_0402_27k".
# Field "BR ID" with value "BRE-000345" added to symbol "R_0402_29k4".
# Field "BR ID" with value "BRE-000346" added to symbol "R_0402_2k".
# Field "BR ID" with value "BRE-000347" added to symbol "R_0402_2k2".
# Field "BR ID" with value "BRE-000348" added to symbol "R_0402_2k49".
# Field "BR ID" with value "BRE-000349" added to symbol "R_0402_30k".
# Field "BR ID" with value "BRE-000350" added to symbol "R_0402_316k".
# Field "BR ID" with value "BRE-000351" added to symbol "R_0402_31k2".
# Field "BR ID" with value "BRE-000352" added to symbol "R_0402_31k6".
# Field "BR ID" with value "BRE-000353" added to symbol "R_0402_330R".
# Field "BR ID" with value "BRE-000354" added to symbol "R_0402_33k".
# Field "BR ID" with value "BRE-000355" added to symbol "R_0402_36k5".
# Field "BR ID" with value "BRE-000356" added to symbol "R_0402_37k4".
# Field "BR ID" with value "BRE-000357" added to symbol "R_0402_38k3".
# Field "BR ID" with value "BRE-000358" added to symbol "R_0402_39k2".
# Field "BR ID" with value "BRE-000359" added to symbol "R_0402_3k".
# Field "BR ID" with value "BRE-000360" added to symbol "R_0402_3k9".
# Field "BR ID" with value "BRE-000361" added to symbol "R_0402_40k2".
# Field "BR ID" with value "BRE-000362" added to symbol "R_0402_43k".
# Field "BR ID" with value "BRE-000363" added to symbol "R_0402_45k3".
# Field "BR ID" with value "BRE-000364" added to symbol "R_0402_470R".
# Field "BR ID" with value "BRE-000365" added to symbol "R_0402_470k".
# Field "BR ID" with value "BRE-000366" added to symbol "R_0402_47k".
# Field "BR ID" with value "BRE-000367" added to symbol "R_0402_47k 0.1%".
# Field "BR ID" with value "BRE-000368" added to symbol "R_0402_499k".
# Field "BR ID" with value "BRE-000369" added to symbol "R_0402_49R9".
# Field "BR ID" with value "BRE-000370" added to symbol "R_0402_49k9".
# Field "BR ID" with value "BRE-000371" added to symbol "R_0402_4k32".
# Field "BR ID" with value "BRE-000372" added to symbol "R_0402_4k7".
# Field "BR ID" with value "BRE-000373" added to symbol "R_0402_4k7_0.1%".
# Field "BR ID" with value "BRE-000374" added to symbol "R_0402_4k87".
# Field "BR ID" with value "BRE-000375" added to symbol "R_0402_4k99".
# Field "BR ID" with value "BRE-000376" added to symbol "R_0402_500R".
# Field "BR ID" with value "BRE-000377" added to symbol "R_0402_50R".
# Field "BR ID" with value "BRE-000378" added to symbol "R_0402_56k".
# Field "BR ID" with value "BRE-000379" added to symbol "R_0402_59k".
# Field "BR ID" with value "BRE-000380" added to symbol "R_0402_5k1".
# Field "BR ID" with value "BRE-000381" added to symbol "R_0402_5k9".
# Field "BR ID" with value "BRE-000382" added to symbol "R_0402_620R".
# Field "BR ID" with value "BRE-000383" added to symbol "R_0402_62k".
# Field "BR ID" with value "BRE-000384" added to symbol "R_0402_64k9".
# Field "BR ID" with value "BRE-000385" added to symbol "R_0402_66k5".
# Field "BR ID" with value "BRE-000386" added to symbol "R_0402_681R".
# Field "BR ID" with value "BRE-000387" added to symbol "R_0402_68k1".
# Field "BR ID" with value "BRE-000388" added to symbol "R_0402_6k04_1%".
# Field "BR ID" with value "BRE-000389" added to symbol "R_0402_6k49".
# Field "BR ID" with value "BRE-000390" added to symbol "R_0402_73k2".
# Field "BR ID" with value "BRE-000391" added to symbol "R_0402_75R".
# Field "BR ID" with value "BRE-000392" added to symbol "R_0402_75k".
# Field "BR ID" with value "BRE-000393" added to symbol "R_0402_78k7".
# Field "BR ID" with value "BRE-000394" added to symbol "R_0402_7k5".
# Field "BR ID" with value "BRE-000395" added to symbol "R_0402_80k6".
# Field "BR ID" with value "BRE-000396" added to symbol "R_0402_820R".
# Field "BR ID" with value "BRE-000397" added to symbol "R_0402_88k7".
# Field "BR ID" with value "BRE-000398" added to symbol "R_0402_93k1".
# Field "BR ID" with value "BRE-000399" added to symbol "R_0402_9k31".
# Field "BR ID" with value "BRE-000400" added to symbol "R_0402_9k65".
# BR_Resistors_0603
# Field "BR ID" with value "BRE-000401" added to symbol "R_0603_10k".
# BR_Resistors_0805
# Field "BR ID" with value "BRE-000402" added to symbol "R_0805_0R".
# Field "BR ID" with value "BRE-000403" added to symbol "R_0805_9mR".
# BR_Resistors_1206
# Field "BR ID" with value "BRE-000404" added to symbol "R_1206_100mR".
# BR_Resistors_Shunts
# Field "BR ID" with value "BRE-000405" added to symbol "WSKW0612L5000FEA".
# BR_Resistors_Thermistors
# Field "BR ID" with value "BRE-000406" added to symbol "Thermistor_0201_10k_3380K_1%".
# Field "BR ID" with value "BRE-000407" added to symbol "Thermistor_0402_10k".
# Field "BR ID" with value "BRE-000408" added to symbol "Thermistor_0402_15k".
# BR_Switches
# Field "BR ID" with value "BRE-000409" added to symbol "450404015514".
# Field "BR ID" with value "BRE-000410" added to symbol "CFS-0400TB".
# Field "BR ID" with value "BRE-000411" added to symbol "CHS-02TA".
# Field "BR ID" with value "BRE-000412" added to symbol "SLW-66527511-SMT-TR".
# Field "BR ID" with value "BRE-000413" added to symbol "TS-1088-AR02016".
# BR_Transistors
# Field "BR ID" with value "BRE-000414" added to symbol "BC807W".
# Field "BR ID" with value "BRE-000415" added to symbol "BC856B-7-F".
# Field "BR ID" with value "BRE-000416" added to symbol "CSD18543Q3A".
# Field "BR ID" with value "BRE-000417" added to symbol "DMN2990UDJ-7".
# Field "BR ID" with value "BRE-000418" added to symbol "DMP6023LE-13".
# Field "BR ID" with value "BRE-000419" added to symbol "DMP6023LSS-13".
# Field "BR ID" with value "BRE-000420" added to symbol "G1006LE".
# Field "BR ID" with value "BRE-000421" added to symbol "IRFH5301TRPBF".
# Field "BR ID" with value "BRE-000422" added to symbol "ISC230N10NM6ATMA1".
# Field "BR ID" with value "BRE-000423" added to symbol "MMBT3904L".
# Field "BR ID" with value "BRE-000424" added to symbol "MMBT3904W".
# Field "BR ID" with value "BRE-000425" added to symbol "MMBT3906L".
# Field "BR ID" with value "BRE-000426" added to symbol "NCE60P04Y".
# Field "BR ID" with value "BRE-000427" added to symbol "NTGS5120PT1G".
# Field "BR ID" with value "BRE-000428" added to symbol "NXV55UNR".
# Field "BR ID" with value "BRE-000429" added to symbol "SI2305CDS-T1-GE3".
# Field "BR ID" with value "BRE-000430" added to symbol "SQJ974EP".
# Field "BR ID" with value "BRE-000431" added to symbol "SiR500DP".
# C:\Users\JacobBrotmanKrass\.conda\envs\condaenv\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
jlc_df = pd.read_excel(r"C:\Users\JacobBrotmanKrass\Documents\GitHub\br-components-database\jlc-scraper\csv\Parts Inventory on JLCPCB.xlsx")
# Out:
# C:\Users\JacobBrotmanKrass\.conda\envs\condaenv\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
parts_df.set_index("BR ID").to_excel("C:/Users/JacobBrotmanKrass/Documents/Parts_Library.xlsx")

# %%
parts_df
# Out:
#              ID                         Name  \
# 0    BRE-000000     C_0201_100nF_25V_X7R_10%
# 1    BRE-000001      C_0201_10nF_25V_X7R_10%
# 2    BRE-000002        C_0201_1nF_50V_C0G_1%
# 3    BRE-000003       C_0201_1uF_16V_X5R_10%
# 4    BRE-000004     C_0201_220nF_25V_X5R_10%
# ..          ...                          ...
# 471  BRE-000471  TP_SQUARE_SMT_3.4mm_x_1.8mm
# 472  BRE-000472             TP_SQUARE_TH_1mm
# 473  BRE-000473             TP_SQUARE_TH_2mm
# 474  BRE-000474           TP_SQUARE_TH_500um
# 475  BRE-000475                   Tether-Art
#
#                                            Description               Value  \
# 0            100nF ±10% 25V X7R 0201 Ceramic Capacitor           100nF 25V
# 1             10nF ±10% 25V X7R 0201 Ceramic Capacitor            10nF 25V
# 2               1nF ±1% 50V C0G 0201 Ceramic Capacitor          1nF 50V 1%
# 3              1uF ±10% 16V X5R 0201 Ceramic Capacitor             1uF 16V
# 4            220nF ±10% 25V X5R 0201 Ceramic Capacitor           220nF 25V
# ..                                                 ...                 ...
# 471  PC Test Point, Miniature Phosphor Bronze Silve...                5017
# 472                              test pad through hole  TP_SQUARE_TH_500um
# 473                             test pad, through hole    TP_SQUARE_TH_2mm
# 474                              test pad through hole  TP_SQUARE_TH_500um
# 475
#
#                                            Symbol  \
# 0     BR_Capacitors_0201:C_0201_100nF_25V_X7R_10%
# 1      BR_Capacitors_0201:C_0201_10nF_25V_X7R_10%
# 2        BR_Capacitors_0201:C_0201_1nF_50V_C0G_1%
# 3       BR_Capacitors_0201:C_0201_1uF_16V_X5R_10%
# 4     BR_Capacitors_0201:C_0201_220nF_25V_X5R_10%
# ..                                            ...
# 471  BR_Virtual_Parts:TP_SQUARE_SMT_3.4mm_x_1.8mm
# 472             BR_Virtual_Parts:TP_SQUARE_TH_1mm
# 473             BR_Virtual_Parts:TP_SQUARE_TH_2mm
# 474           BR_Virtual_Parts:TP_SQUARE_TH_500um
# 475                   BR_Virtual_Parts:Tether-Art
#
#                                    Footprint  \
# 0    BR_Passives:C_0201_0603Metric-minimized
# 1    BR_Passives:C_0201_0603Metric-minimized
# 2    BR_Passives:C_0201_0603Metric-minimized
# 3    BR_Passives:C_0201_0603Metric-minimized
# 4    BR_Passives:C_0201_0603Metric-minimized
# ..                                       ...
# 471           BR_Virtual_Parts:KEYSTONE_5017
# 472        BR_Virtual_Parts:TP_SQUARE_TH_1mm
# 473        BR_Virtual_Parts:TP_SQUARE_TH_2mm
# 474      BR_Virtual_Parts:TP_SQUARE_TH_500um
# 475              BR_Virtual_Parts:Tether-Art
#
#                                              Datasheet          Manufacturer  \
# 0    https://www.lcsc.com/datasheet/lcsc_datasheet_...    Murata Electronics
# 1    https://search.murata.co.jp/Ceramy/image/img/A...    Murata Electronics
# 2    https://www.lcsc.com/datasheet/lcsc_datasheet_...    Murata Electronics
# 3    https://www.mouser.com/datasheet/2/281/1/GRM03...    Murata Electronics
# 4    https://www.lcsc.com/datasheet/lcsc_datasheet_...    Murata Electronics
# ..                                                 ...                   ...
# 471  https://www.keyelco.com/userAssets/file/M65p55...  Keystone Electronics
# 472                                                  ~                     ~
# 473                                                  ~                     ~
# 474                                                  ~                     ~
# 475                                                                     None
#
#                     MPN         Category
# 0    GRM033R61E104KE14J  Capacitors_0201
# 1    GRM033R71E103KE14D  Capacitors_0201
# 2    GRM0335C1H102JE01D  Capacitors_0201
# 3    GRM033R61C105ME15D  Capacitors_0201
# 4    GRM033R61E224KE01D  Capacitors_0201
# ..                  ...              ...
# 471                5017    Virtual_Parts
# 472                   ~    Virtual_Parts
# 473                   ~    Virtual_Parts
# 474                   ~    Virtual_Parts
# 475                None    Virtual_Parts
#
# [476 rows x 10 columns]

# %%
jlc_df = jlc_df.rename(columns={"JLCPCB Part #":"SPN"})
merged_df = pd.merge(vendors_df.set_index("SPN"), jlc_df.set_index("SPN"), on="SPN", how='left')

# %%
merged_df["Stock"] = merged_df[["JLCPCB Parts Qty", "Global Sourcing Parts Qty", "Consigned Parts Qty"]].max(axis=1)

# %%
merged_df.reset_index()
# Out:
#                        SPN          ID Supplier   Stock    Category  \
# 0           490-14571-1-ND  BRE-000000  DigiKey     NaN         NaN
# 1     81-GRM033R61E104KE4J  BRE-000000   Mouser     NaN         NaN
# 2                 C2649540  BRE-000000   JLCPCB  5000.0  Capacitors
# 3           490-14454-2-ND  BRE-000001  DigiKey     NaN         NaN
# 4      81-GRM0335C1E12FA1D  BRE-000001   Mouser     NaN         NaN
# ...                    ...         ...      ...     ...         ...
# 1000           C9900082548  BRE-000445   JLCPCB     NaN         NaN
# 1001              C2916352  BRE-000446   JLCPCB     NaN         NaN
# 1002              C2916351  BRE-000447   JLCPCB     NaN         NaN
# 1003          36-5017CT-ND  BRE-000471  DigiKey     NaN         NaN
# 1004               C238130  BRE-000471   JLCPCB     NaN         NaN
#
#               MFR Part # Footprint  JLCPCB Parts Qty  \
# 0                    NaN       NaN               NaN
# 1                    NaN       NaN               NaN
# 2     GRM033R61E104KE14J      0201            5000.0
# 3                    NaN       NaN               NaN
# 4                    NaN       NaN               NaN
# ...                  ...       ...               ...
# 1000                 NaN       NaN               NaN
# 1001                 NaN       NaN               NaN
# 1002                 NaN       NaN               NaN
# 1003                 NaN       NaN               NaN
# 1004                 NaN       NaN               NaN
#
#       Global Sourcing Parts Qty  Consigned Parts Qty
# 0                           NaN                  NaN
# 1                           NaN                  NaN
# 2                           0.0                  0.0
# 3                           NaN                  NaN
# 4                           NaN                  NaN
# ...                         ...                  ...
# 1000                        NaN                  NaN
# 1001                        NaN                  NaN
# 1002                        NaN                  NaN
# 1003                        NaN                  NaN
# 1004                        NaN                  NaN
#
# [1005 rows x 10 columns]

# %%
vendor_stock_df = merged_df.reset_index()[["ID", "Supplier", "SPN", "Stock"]]
vendor_stock_df.set_index(["ID", "SPN"], inplace=True)
vendor_stock_df
# Out:
#                                 Supplier   Stock
# ID         SPN
# BRE-000000 490-14571-1-ND        DigiKey     NaN
#            81-GRM033R61E104KE4J   Mouser     NaN
#            C2649540               JLCPCB  5000.0
# BRE-000001 490-14454-2-ND        DigiKey     NaN
#            81-GRM0335C1E12FA1D    Mouser     NaN
# ...                                  ...     ...
# BRE-000445 C9900082548            JLCPCB     NaN
# BRE-000446 C2916352               JLCPCB     NaN
# BRE-000447 C2916351               JLCPCB     NaN
# BRE-000471 36-5017CT-ND          DigiKey     NaN
#            C238130                JLCPCB     NaN
#
# [1005 rows x 2 columns]

# %%
vendor_stock_df
# Out:
#              ID Supplier       SPN  Stock
# 0    BRE-000000   JLCPCB  C2649540   5000
# 1    BRE-000003   JLCPCB   C335102   1000
# 2    BRE-000005   JLCPCB    C76926      0
# 3    BRE-000007   JLCPCB  C3886751   1000
# 4    BRE-000009   JLCPCB   C161434   1000
# ..          ...      ...       ...    ...
# 122  BRE-000410   JLCPCB  C2921584     60
# 123  BRE-000413   JLCPCB   C720477    100
# 124  BRE-000419   JLCPCB   C154911    100
# 125  BRE-000426   JLCPCB   C102608      0
# 126  BRE-000430   JLCPCB   C727845     30
#
# [127 rows x 4 columns]

# %%
id = ['00', '01', '01', '02']
stock = [15, 12, 7, 0]
spn = ['C12','C19','C13','C29']
test_df = pd.DataFrame(data={"ID":id, "Stock":stock, "SPN":spn}).set_index(["ID", "SPN"])

# %%
vendor_stock_df
# Out:
#                                 Supplier   Stock
# ID         SPN
# BRE-000000 490-14571-1-ND        DigiKey     NaN
#            81-GRM033R61E104KE4J   Mouser     NaN
#            C2649540               JLCPCB  5000.0
# BRE-000001 490-14454-2-ND        DigiKey     NaN
#            81-GRM0335C1E12FA1D    Mouser     NaN
# ...                                  ...     ...
# BRE-000445 C9900082548            JLCPCB     NaN
# BRE-000446 C2916352               JLCPCB     NaN
# BRE-000447 C2916351               JLCPCB     NaN
# BRE-000471 36-5017CT-ND          DigiKey     NaN
#            C238130                JLCPCB     NaN
#
# [1005 rows x 2 columns]

# %%
vendor_stock_df.to_excel("C:/Users/JacobBrotmanKrass/Documents/output.xlsx")

# %%
read_df = pd.read_excel("C:/Users/JacobBrotmanKrass/Documents/output.xlsx", index_col=[0, 1])
read_df[read_df.Supplier == "JLCPCB"]
# Out:
#                        Supplier   Stock
# ID         SPN
# BRE-000000 C2649540      JLCPCB  5000.0
# BRE-000001 C85930        JLCPCB     NaN
# BRE-000002 C3870067      JLCPCB     NaN
# BRE-000003 C335102       JLCPCB  1000.0
# BRE-000004 C701263       JLCPCB     NaN
# ...                         ...     ...
# BRE-000444 C2916384      JLCPCB     NaN
# BRE-000445 C9900082548   JLCPCB     NaN
# BRE-000446 C2916352      JLCPCB     NaN
# BRE-000447 C2916351      JLCPCB     NaN
# BRE-000471 C238130       JLCPCB     NaN
#
# [356 rows x 2 columns]
